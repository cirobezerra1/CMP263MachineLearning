# %% [markdown]
# # 00.Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from math import sqrt
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # 01.Helpers

# %% [markdown]
# ## 01.01 Constants

# %%
features_datasus = ['date', 'hospitalizations','average_stay', 'deaths', 'mortality_rate']

# %%
test_start_date = "2017-01-01"

# %% [markdown]
# ## 01.02 Functions

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
def train_test_split(df, test_date, target_variable):
    # separação por tempo
    df_train = df[df.index < test_date]
    df_test  = df[df.index >= test_date]

    # remoção da variável target
    y_train = df_train[target_variable]
    y_test  = df_test[target_variable]

    df_train = df_train.drop(columns=target_variable).copy()
    df_test  = df_test.drop(columns=target_variable).copy()

    print(df_train.shape, y_train.shape)
    print(df_test.shape, y_test.shape)

    return df_train, df_test, y_train, y_test

# %%
def data_normalization(df_train, df_test, y_train, y_test):
    # Para as features
    scaler               = MinMaxScaler(feature_range=(0, 1))
    df_train_scaled      = scaler.fit_transform(df_train)
    df_test_scaled       = scaler.transform(df_test)

    # Para a variável alvo
    scaler_target       = MinMaxScaler(feature_range=(0, 1))
    y_train_scaled      = scaler_target.fit_transform(y_train.to_frame())
    y_test_scaled       = scaler_target.transform(y_test.to_frame())

    print(df_train_scaled.shape, y_train_scaled.shape)
    print(df_test_scaled.shape, y_test_scaled.shape)

    return scaler, scaler_target, df_train_scaled, df_test_scaled, y_train_scaled, y_test_scaled

# %%
def data_reconversion(scaler, scaler_target, df_train_scaled, df_test_scaled, y_train_scaled, y_test_scaled, y_pred):
    df_train_original = scaler.inverse_transform(df_train_scaled)
    df_test_original = scaler.inverse_transform(df_test_scaled)

    y_train_original = scaler_target.inverse_transform(y_train_scaled)
    y_test_original = scaler_target.inverse_transform(y_test_scaled)
    y_pred_original = scaler_target.inverse_transform(y_pred)

    return df_train_original, df_test_original, y_train_original, y_test_original, y_pred_original

# %%
def metrics(y, predicted):
    mae = mean_absolute_error(y, predicted)
    mse = mean_squared_error(y, predicted)
    rmse = mean_squared_error(y, predicted)
    mape = np.mean(np.abs((y - predicted) / y)) * 100
    r2 = r2_score(y, predicted)
    return mae, mse, rmse, mape, r2

def print_metrics(y, predicted):
    mae, mse, rmse, mape, r2 = metrics(y, predicted)
    print(f"Mean Absolute Error (MAE): {mae:.2f}")
    print(f"Mean Squared Error (MSE): {mse:.2f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
    print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
    print(f"R-Squared (R²): {r2:.2f}")

# %% [markdown]
# # 02.Importing Datasets

# %%
dataset = pd.read_csv('../Preprocessing/dataset.csv', 
                   header=0, 
                   index_col=0)

# values = dataset.values
dataset
# Out:
#             hospitalizations  hospitalizations_lag_3  average_stay_lag_3  \
# date
# 2000-12-01            4266.0                  4365.0                 6.4
# 2001-01-01            4032.0                  4388.0                 6.3
# 2001-02-01            3888.0                  4329.0                 6.1
# 2001-03-01            3658.0                  4266.0                 6.1
# 2001-04-01            4022.0                  4032.0                 5.9
# ...                      ...                     ...                 ...
# 2024-05-01            3172.0                  3176.0                 6.4
# 2024-06-01            3640.0                  3390.0                 6.7
# 2024-07-01            3689.0                  3329.0                 6.5
# 2024-08-01            3846.0                  3172.0                 6.7
# 2024-09-01            3426.0                  3640.0                 6.6
#
#             deaths_lag_3  mortality_rate_lag_3  \
# date
# 2000-12-01         293.0                  6.71
# 2001-01-01         275.0                  6.27
# 2001-02-01         258.0                  5.96
# 2001-03-01         242.0                  5.67
# 2001-04-01         218.0                  5.41
# ...                  ...                   ...
# 2024-05-01         264.0                  8.31
# 2024-06-01         277.0                  8.17
# 2024-07-01         308.0                  9.25
# 2024-08-01         313.0                  9.87
# 2024-09-01         329.0                  9.04
#
#             hospitalizations_lag_3_12m_window  average_stay_lag_3_12m_window  \
# date
# 2000-12-01                        4277.500000                       5.900000
# 2001-01-01                        4257.250000                       5.925000
# 2001-02-01                        4256.583333                       5.933333
# 2001-03-01                        4265.166667                       5.966667
# 2001-04-01                        4263.833333                       5.975000
# ...                                       ...                            ...
# 2024-05-01                        3490.333333                       6.950000
# 2024-06-01                        3503.083333                       6.916667
# 2024-07-01                        3510.166667                       6.891667
# 2024-08-01                        3497.666667                       6.866667
# 2024-09-01                        3519.833333                       6.850000
#
#             deaths_lag_3_12m_window  mortality_rate_lag_3_12m_window  \
# date
# 2000-12-01               245.333333                         5.728333
# 2001-01-01               246.250000                         5.775833
# 2001-02-01               248.083333                         5.819167
# 2001-03-01               250.833333                         5.873333
# 2001-04-01               250.666667                         5.871667
# ...                             ...                              ...
# 2024-05-01               316.416667                         9.045833
# 2024-06-01               316.500000                         9.015833
# 2024-07-01               321.500000                         9.150000
# 2024-08-01               319.500000                         9.127500
# 2024-09-01               318.750000                         9.045833
#
#             heat_index  ...  heat_index99  heat_index95  temperature_mean  \
# date                    ...
# 2000-12-01   24.154261  ...       37.8966       33.5380         23.575000
# 2001-01-01   26.316156  ...       37.8471       34.6685         25.136962
# 2001-02-01   27.119464  ...       37.7548       35.3940         25.691071
# 2001-03-01   26.113387  ...       36.7670       34.4155         24.985349
# 2001-04-01   21.383903  ...       31.0030       28.0215         21.038333
# ...                ...  ...           ...           ...               ...
# 2024-05-01   16.708185  ...       33.1822       27.3330         16.684946
# 2024-06-01   17.283889  ...       29.7834       26.8025         17.371111
# 2024-07-01   13.313495  ...       26.8167       21.7780         13.736022
# 2024-08-01   15.274395  ...       28.9485       24.4525         15.594758
# 2024-09-01   18.789722  ...       31.8239       26.9330         18.740278
#
#             temperature_max  temperature_min  wind_speed_mean  humidity_mean  \
# date
# 2000-12-01             35.4             13.4         1.826613      70.836022
# 2001-01-01             35.4             17.0         1.777016      75.375000
# 2001-02-01             34.2             20.2         1.916518      76.424107
# 2001-03-01             34.4             16.3         1.629704      76.383065
# 2001-04-01             30.8             11.9         1.455139      81.152778
# ...                     ...              ...              ...            ...
# 2024-05-01             32.5              7.1         1.345027      85.837366
# 2024-06-01             31.5              4.6         1.265139      80.636111
# 2024-07-01             28.9              3.4         1.123387      81.887097
# 2024-08-01             31.1              4.5         1.394892      78.956989
# 2024-09-01             33.7              9.0         1.534722      80.148611
#
#             lag_heat_index_1  lag_heat_index_2  lag_heat_index_3
# date
# 2000-12-01         21.132403         19.318992         15.300694
# 2001-01-01         24.154261         21.132403         19.318992
# 2001-02-01         26.316156         24.154261         21.132403
# 2001-03-01         27.119464         26.316156         24.154261
# 2001-04-01         26.113387         27.119464         26.316156
# ...                      ...               ...               ...
# 2024-05-01         22.136556         25.621075         27.636221
# 2024-06-01         16.708185         22.136556         25.621075
# 2024-07-01         17.283889         16.708185         22.136556
# 2024-08-01         13.313495         17.283889         16.708185
# 2024-09-01         15.274395         13.313495         17.283889
#
# [286 rows x 22 columns]

# %%
dataset.columns
# Out:
# Index(['hospitalizations', 'hospitalizations_lag_3', 'average_stay_lag_3',
#        'deaths_lag_3', 'mortality_rate_lag_3',
#        'hospitalizations_lag_3_12m_window', 'average_stay_lag_3_12m_window',
#        'deaths_lag_3_12m_window', 'mortality_rate_lag_3_12m_window',
#        'heat_index', 'heat_index_sum', 'heat_index_std', 'heat_index99',
#        'heat_index95', 'temperature_mean', 'temperature_max',
#        'temperature_min', 'wind_speed_mean', 'humidity_mean',
#        'lag_heat_index_1', 'lag_heat_index_2', 'lag_heat_index_3'],
#       dtype='object')

# %% [markdown]
# # 03.Preprocessing

# %% [markdown]
# ## 03.01 Remoção ano 2000

# %%
dataset = dataset[dataset.index < "2020-01-01"]

test_start_date = '2017-01-01'

# %% [markdown]
# # 04.Model training

# %% [markdown]
# ## 04.01 Split train and test

# %%
df_train, df_test, y_train, y_test = train_test_split(dataset, test_start_date, 'hospitalizations')
# Out:
# (193, 21) (193,)
# (36, 21) (36,)

# %% [markdown]
# ## 04.02 Normalization

# %%
scaler, scaler_target, df_train_scaled, df_test_scaled, y_train_scaled, y_test_scaled = data_normalization(df_train, df_test, y_train, y_test)
# Out:
# (193, 21) (193, 1)
# (36, 21) (36, 1)

# %% [markdown]
# ## 04.03 Grouping columns

# %%
# df_train_scaled = np.hstack((df_train_scaled, y_train_scaled.reshape(-1, 1)))
# df_test_scaled = np.hstack((df_test_scaled, y_test_scaled.reshape(-1, 1)))

# %% [markdown]
# ## 04.04 Reshape input to be 3D [samples, timesteps, features]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = df_train_scaled.reshape((df_train_scaled.shape[0], 1, df_train_scaled.shape[1]))
test_X = df_test_scaled.reshape((df_test_scaled.shape[0], 1, df_test_scaled.shape[1]))

print(train_X.shape, y_train_scaled.shape, test_X.shape, y_test_scaled.shape)
# Out:
# (193, 1, 21) (193, 1) (36, 1, 21) (36, 1)

# %% [markdown]
# ## 04.05 Recurrent network

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# design network
model = Sequential()
model.add(LSTM(22, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(22, return_sequences=True))
model.add(LSTM(11))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# fit network
history = model.fit(train_X, 
                    y_train_scaled, 
                    epochs=150, 
                    batch_size=12, 
                    validation_data=(test_X, y_test_scaled), 
                    verbose=2, 
                    callbacks=[early_stopping],
                    shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/150
# /home/thiery/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 - 5s - 299ms/step - loss: 0.2304 - val_loss: 0.0610
# Epoch 2/150
# 17/17 - 0s - 6ms/step - loss: 0.1758 - val_loss: 0.0242
# Epoch 3/150
# 17/17 - 0s - 6ms/step - loss: 0.1052 - val_loss: 0.0234
# Epoch 4/150
# 17/17 - 0s - 8ms/step - loss: 0.0606 - val_loss: 0.0587
# Epoch 5/150
# 17/17 - 0s - 6ms/step - loss: 0.0416 - val_loss: 0.0414
# Epoch 6/150
# 17/17 - 0s - 6ms/step - loss: 0.0417 - val_loss: 0.0371
# Epoch 7/150
# 17/17 - 0s - 6ms/step - loss: 0.0402 - val_loss: 0.0370
# Epoch 8/150
# 17/17 - 0s - 6ms/step - loss: 0.0370 - val_loss: 0.0343
# Epoch 9/150
# 17/17 - 0s - 6ms/step - loss: 0.0339 - val_loss: 0.0305
# Epoch 10/150
# 17/17 - 0s - 6ms/step - loss: 0.0308 - val_loss: 0.0265
# Epoch 11/150
# 17/17 - 0s - 6ms/step - loss: 0.0273 - val_loss: 0.0222
# Epoch 12/150
# 17/17 - 0s - 6ms/step - loss: 0.0235 - val_loss: 0.0176
# Epoch 13/150
# 17/17 - 0s - 6ms/step - loss: 0.0196 - val_loss: 0.0132
# Epoch 14/150
# 17/17 - 0s - 6ms/step - loss: 0.0160 - val_loss: 0.0097
# Epoch 15/150
# 17/17 - 0s - 6ms/step - loss: 0.0131 - val_loss: 0.0076
# Epoch 16/150
# 17/17 - 0s - 10ms/step - loss: 0.0111 - val_loss: 0.0067
# Epoch 17/150
# 17/17 - 0s - 8ms/step - loss: 0.0101 - val_loss: 0.0065
# Epoch 18/150
# 17/17 - 0s - 8ms/step - loss: 0.0097 - val_loss: 0.0065
# Epoch 19/150
# 17/17 - 0s - 7ms/step - loss: 0.0095 - val_loss: 0.0064
# Epoch 20/150
# 17/17 - 0s - 12ms/step - loss: 0.0094 - val_loss: 0.0064
# Epoch 21/150
# 17/17 - 0s - 10ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 22/150
# 17/17 - 0s - 9ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 23/150
# 17/17 - 0s - 16ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 24/150
# 17/17 - 0s - 8ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 25/150
# 17/17 - 0s - 7ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 26/150
# 17/17 - 0s - 6ms/step - loss: 0.0091 - val_loss: 0.0061
# Epoch 27/150
# 17/17 - 0s - 7ms/step - loss: 0.0091 - val_loss: 0.0061
# Epoch 28/150
# 17/17 - 0s - 8ms/step - loss: 0.0091 - val_loss: 0.0060
# Epoch 29/150
# 17/17 - 0s - 7ms/step - loss: 0.0090 - val_loss: 0.0060
# Epoch 30/150
# 17/17 - 0s - 7ms/step - loss: 0.0090 - val_loss: 0.0060
# Epoch 31/150
# 17/17 - 0s - 6ms/step - loss: 0.0090 - val_loss: 0.0059
# Epoch 32/150
# 17/17 - 0s - 6ms/step - loss: 0.0089 - val_loss: 0.0059
# Epoch 33/150
# 17/17 - 0s - 6ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 34/150
# 17/17 - 0s - 6ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 35/150
# 17/17 - 0s - 7ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 36/150
# 17/17 - 0s - 6ms/step - loss: 0.0088 - val_loss: 0.0057
# Epoch 37/150
# 17/17 - 0s - 6ms/step - loss: 0.0088 - val_loss: 0.0057
# Epoch 38/150
# 17/17 - 0s - 6ms/step - loss: 0.0088 - val_loss: 0.0057
# Epoch 39/150
# 17/17 - 0s - 7ms/step - loss: 0.0088 - val_loss: 0.0056
# Epoch 40/150
# 17/17 - 0s - 6ms/step - loss: 0.0087 - val_loss: 0.0056
# Epoch 41/150
# 17/17 - 0s - 6ms/step - loss: 0.0087 - val_loss: 0.0056
# Epoch 42/150
# 17/17 - 0s - 7ms/step - loss: 0.0087 - val_loss: 0.0056
# Epoch 43/150
# 17/17 - 0s - 7ms/step - loss: 0.0087 - val_loss: 0.0055
# Epoch 44/150
# 17/17 - 0s - 7ms/step - loss: 0.0086 - val_loss: 0.0055
# Epoch 45/150
# 17/17 - 0s - 6ms/step - loss: 0.0086 - val_loss: 0.0055
# Epoch 46/150
# 17/17 - 0s - 6ms/step - loss: 0.0086 - val_loss: 0.0054
# Epoch 47/150
# 17/17 - 0s - 6ms/step - loss: 0.0086 - val_loss: 0.0054
# Epoch 48/150
# 17/17 - 0s - 6ms/step - loss: 0.0085 - val_loss: 0.0054
# Epoch 49/150
# 17/17 - 0s - 6ms/step - loss: 0.0085 - val_loss: 0.0054
# Epoch 50/150
# 17/17 - 0s - 6ms/step - loss: 0.0085 - val_loss: 0.0053
# Epoch 51/150
# 17/17 - 0s - 6ms/step - loss: 0.0085 - val_loss: 0.0053
# Epoch 52/150
# 17/17 - 0s - 7ms/step - loss: 0.0084 - val_loss: 0.0053
# Epoch 53/150
# 17/17 - 0s - 6ms/step - loss: 0.0084 - val_loss: 0.0053
# Epoch 54/150
# 17/17 - 0s - 6ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 55/150
# 17/17 - 0s - 6ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 56/150
# 17/17 - 0s - 6ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 57/150
# 17/17 - 0s - 8ms/step - loss: 0.0083 - val_loss: 0.0052
# Epoch 58/150
# 17/17 - 0s - 7ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 59/150
# 17/17 - 0s - 7ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 60/150
# 17/17 - 0s - 9ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 61/150
# 17/17 - 0s - 7ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 62/150
# 17/17 - 0s - 8ms/step - loss: 0.0082 - val_loss: 0.0050
# Epoch 63/150
# 17/17 - 0s - 6ms/step - loss: 0.0082 - val_loss: 0.0050
# Epoch 64/150
# 17/17 - 0s - 9ms/step - loss: 0.0082 - val_loss: 0.0050
# Epoch 65/150
# 17/17 - 0s - 9ms/step - loss: 0.0082 - val_loss: 0.0050
# Epoch 66/150
# 17/17 - 0s - 7ms/step - loss: 0.0082 - val_loss: 0.0050
# Epoch 67/150
# 17/17 - 0s - 7ms/step - loss: 0.0082 - val_loss: 0.0049
# Epoch 68/150
# 17/17 - 0s - 9ms/step - loss: 0.0081 - val_loss: 0.0049
# Epoch 69/150
# 17/17 - 0s - 7ms/step - loss: 0.0081 - val_loss: 0.0049
# Epoch 70/150
# 17/17 - 0s - 6ms/step - loss: 0.0081 - val_loss: 0.0049
# Epoch 71/150
# 17/17 - 0s - 8ms/step - loss: 0.0081 - val_loss: 0.0049
# Epoch 72/150
# 17/17 - 0s - 6ms/step - loss: 0.0081 - val_loss: 0.0048
# Epoch 73/150
# 17/17 - 0s - 8ms/step - loss: 0.0081 - val_loss: 0.0048
# Epoch 74/150
# 17/17 - 0s - 8ms/step - loss: 0.0080 - val_loss: 0.0048
# Epoch 75/150
# 17/17 - 0s - 8ms/step - loss: 0.0080 - val_loss: 0.0048
# Epoch 76/150
# 17/17 - 0s - 6ms/step - loss: 0.0080 - val_loss: 0.0048
# Epoch 77/150
# 17/17 - 0s - 6ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 78/150
# 17/17 - 0s - 6ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 79/150
# 17/17 - 0s - 6ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 80/150
# 17/17 - 0s - 6ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 81/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0047
# Epoch 82/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0047
# Epoch 83/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 84/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 85/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 86/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 87/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 88/150
# 17/17 - 0s - 6ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 89/150
# 17/17 - 0s - 6ms/step - loss: 0.0078 - val_loss: 0.0046
# Epoch 90/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 91/150
# 17/17 - 0s - 8ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 92/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 93/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 94/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 95/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 96/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 97/150
# 17/17 - 0s - 7ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 98/150
# 17/17 - 0s - 7ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 99/150
# 17/17 - 0s - 7ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 100/150
# 17/17 - 0s - 6ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 101/150
# 17/17 - 0s - 13ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 102/150
# 17/17 - 0s - 12ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 103/150
# 17/17 - 0s - 8ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 104/150
# 17/17 - 0s - 7ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 105/150
# 17/17 - 0s - 7ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 106/150
# 17/17 - 0s - 6ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 107/150
# 17/17 - 0s - 7ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 108/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0044
# Epoch 109/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 110/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 111/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 112/150
# 17/17 - 0s - 6ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 113/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 114/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 115/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 116/150
# 17/17 - 0s - 6ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 117/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 118/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 119/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 120/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 121/150
# 17/17 - 0s - 7ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 122/150
# 17/17 - 0s - 8ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 123/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0043
# Epoch 124/150
# 17/17 - 0s - 9ms/step - loss: 0.0075 - val_loss: 0.0043
# Epoch 125/150
# 17/17 - 0s - 8ms/step - loss: 0.0075 - val_loss: 0.0043
# Epoch 126/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 127/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 128/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 129/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 130/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 131/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 132/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 133/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 134/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 135/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 136/150
# 17/17 - 0s - 7ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 137/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 138/150
# 17/17 - 0s - 8ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 139/150
# 17/17 - 0s - 6ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 140/150
# 17/17 - 0s - 8ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 141/150
# 17/17 - 0s - 8ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 142/150
# 17/17 - 0s - 7ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 143/150
# 17/17 - 0s - 7ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 144/150
# 17/17 - 0s - 7ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 145/150
# 17/17 - 0s - 8ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 146/150
# 17/17 - 0s - 8ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 147/150
# 17/17 - 0s - 6ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 148/150
# 17/17 - 0s - 6ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 149/150
# 17/17 - 0s - 7ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 150/150
# 17/17 - 0s - 8ms/step - loss: 0.0074 - val_loss: 0.0042

# %% [markdown]
# ## 04.06 Prediction

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler_target.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual
test_y = y_test_scaled.reshape((len(y_test_scaled), 1))
inv_y = np.concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler_target.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# calculate RMSE
print_metrics(inv_y, inv_yhat)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step
# Mean Absolute Error (MAE): 116.39
# Mean Squared Error (MSE): 18451.23
# Root Mean Squared Error (RMSE): 18451.23
# Mean Absolute Percentage Error (MAPE): 3.58%
# R-Squared (R²): 0.53

# %%
test_pred = scaler_target.inverse_transform(yhat)
test_test = scaler_target.inverse_transform(test_y.reshape(-1, 1))

print_metrics(test_test, test_pred)
# Out:
# Mean Absolute Error (MAE): 116.39
# Mean Squared Error (MSE): 18451.24
# Root Mean Squared Error (RMSE): 18451.24
# Mean Absolute Percentage Error (MAPE): 3.58%
# R-Squared (R²): 0.53

# %% [markdown]
# ## 04.07 Plot

# %%
index_train = pd.to_datetime(dataset.index)
index_test = dataset.tail(36).index

plt.figure(figsize=(12, 6))
# plt.plot(index_train, dataset['hospitalizations'], color='green', label='Train')
plt.plot(index_test, inv_y, color='green', label='Test')
plt.plot(index_test, inv_yhat, color='red', label='Predicted')
plt.title("Actual vs predicted")
plt.xlabel('years')
plt.ylabel('mortality_rate')
plt.grid(True)
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
